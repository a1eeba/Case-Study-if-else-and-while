# %%
# Aleeba Ghazanfar
# File: Case Study if else and while.ipynb
# Description: This app accepts student names and GPAs
while True:
    last_name = input("Enter student's last name (or 'ZZZ' to quit): ")
    
    if last_name == 'ZZZ':
        print("Goodbye!")
        break
    
    first_name = input("Enter student's first name: ")
    gpa = float(input("Enter student's GPA: "))
    
    print(f"\nStudent: {first_name} {last_name} | GPA: {gpa}")
    
    if gpa >= 3.5:
        print(f"Congratulations! {first_name} {last_name} has made the Dean's List!")
    elif gpa >= 3.25:
        print(f"Congratulations! {first_name} {last_name} has made the Honor Roll!")
    else:
        print(f"{first_name} {last_name} did not qualify for the Dean's List or Honor Roll.")
    
    print("-" * 50)
# Out:
# Enter student's last name (or 'ZZZ' to quit):  ghaz
# Enter student's first name:  alee
# Enter student's GPA:  3.65
# Student: alee ghaz | GPA: 3.65
# Congratulations! alee ghaz has made the Dean's List!
# --------------------------------------------------
# Enter student's last name (or 'ZZZ' to quit):  lop
# Enter student's first name:  gabe
# Enter student's GPA:  3.25
# Student: gabe lop | GPA: 3.25
# Congratulations! gabe lop has made the Honor Roll!
# --------------------------------------------------
# Enter student's last name (or 'ZZZ' to quit):  mad
# Enter student's first name:  reim
# Enter student's GPA:  2.9
# Student: reim mad | GPA: 2.9
# reim mad did not qualify for the Dean's List or Honor Roll.
# --------------------------------------------------
